# %%
class Solution:
  def checkOnesSegment(self, s: str) -> bool:
    return '01' not in s

# %%
s = "1001"
Solution().checkOnesSegment(s=s)
# Out:
# False

# %%
s = "110"
Solution().checkOnesSegment(s=s)
# Out:
# True
