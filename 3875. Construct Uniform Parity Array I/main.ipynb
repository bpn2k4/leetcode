# %%
class Solution:
  def uniformArray(self, nums1: list[int]) -> bool:
    return True

# %%
nums1 = [2, 3]
Solution().uniformArray(nums1=nums1)

# %%
nums1 = [4, 6]
Solution().uniformArray(nums1=nums1)
