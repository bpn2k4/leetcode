# %%
class Solution:
  def countCommas(self, n: int) -> int:
    if n < 1000:
      return 0
    return n - 999

# %%
n = 1002
Solution().countCommas(n=n)
# Out:
# 3

# %%
n = 998
Solution().countCommas(n=n)
# Out:
# 0
