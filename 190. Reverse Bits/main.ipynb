# %%
class Solution:
  def reverseBits(self, n: int) -> int:
    return int(f"{n:032b}"[::-1], 2)

# %%
n = 43261596
Solution().reverseBits(n=n)
# Out:
# 964176192

# %%
n = 2147483644
Solution().reverseBits(n=n)
# Out:
# 1073741822
