# %%
class Solution:
  def toLowerCase(self, s: str) -> str:
    return s.lower()

# %%
s = "Hello"
Solution().toLowerCase(s=s)
# Out:
# 'hello'

# %%
s = "here"
Solution().toLowerCase(s=s)
# Out:
# 'here'

# %%
s = "LOVELY"
Solution().toLowerCase(s=s)
# Out:
# 'lovely'
