# %%
class Solution:
  def minPartitions(self, n: str) -> int:
    return int(max(list(n)))

# %%
n = "32"
Solution().minPartitions(n=n)
# Out:
# 3

# %%
n = "82734"
Solution().minPartitions(n=n)
# Out:
# 8

# %%
n = "27346209830709182346"
Solution().minPartitions(n=n)
# Out:
# 9
