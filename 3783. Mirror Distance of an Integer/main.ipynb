# %%
class Solution:
  def mirrorDistance(self, n: int) -> int:
    return abs(n - int(str(n)[::-1]))

# %%
n = 25
Solution().mirrorDistance(n=n)
# Out:
# 27

# %%
n = 10
Solution().mirrorDistance(n=n)
# Out:
# 9

# %%
n = 7
Solution().mirrorDistance(n=n)
# Out:
# 0
